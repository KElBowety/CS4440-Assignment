# %%
import pandas as pd
import json

# %%
file = open('Data/Timeseries_30.033_31.562_SA2_1kWp_crystSi_14_28deg_0deg_2019_2020.json')
data = json.load(file)
df = pd.json_normalize(data['outputs']['hourly'])
df.describe()
# Out:
#                   P         Gb(i)         Gd(i)         Gr(i)         H_sun  \
# count  17544.000000  17544.000000  17544.000000  17544.000000  17544.000000
# mean     216.939652    204.627289     75.777261      3.072123     17.685180
# std      288.651948    292.951529     93.928433      4.085460     23.113128
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      0.000000      0.000000      0.000000      0.000000
# 50%        0.000000      0.000000      0.000000      0.000000      0.000000
# 75%      478.527500    408.870000    153.602500      6.360000     34.260000
# max      905.400000   1005.410000    486.810000     13.030000     82.750000
#
#                 T2m         WS10m      Int
# count  17544.000000  17544.000000  17544.0
# mean      21.047703      3.859257      0.0
# std        7.940073      1.744795      0.0
# min        2.160000      0.000000      0.0
# 25%       14.740000      2.550000      0.0
# ...
